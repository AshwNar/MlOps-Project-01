# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted to a MongoDB collection
# mango db storos data as key value paire that is why we need to convert the dataframe to a dictionary
data = df.to_dict(orient='records')

# %%
#defining database connection parameters
DB_NAME = "Ml-Pro1"
COLLECTION_NAME = "Pro1-Data"
CONNECTION_URL = "mongodb+srv://ashuofficial1106:5ZXDLa00Ejvo4VAF@cluster0.fr2gc5z.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
#connecting to MongoDB and creating a collection
clinet = pymongo.MongoClient(CONNECTION_URL)
data_base = clinet[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
#inserting data into the collection
rec = collection.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[10], line 2
#       1 #inserting data into the collection
# ----> 2 rec = collection.insert_many(data)
#
# File e:\MLOps_course\MlOps-Project-01\venv_ml_project01\lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File e:\MLOps_course\MlOps-Project-01\venv_ml_project01\lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
# ...
